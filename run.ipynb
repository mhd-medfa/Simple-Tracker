# %% [markdown]
# ## Run inference on video
# ``--source`` specifies directory of the video that we want to run inferencing on
#
# ``--save-vid`` flag in order to save the video into runs/track/exp*
#
# ``--yolo_model`` yolo model
#
# ``--show-vid`` flag in order to visualize the tracking in real-time
#
# ``--classes`` we chose 1 2 3 4 5 6 7 8 that stands for vehicles (bicycle, car, motorcycle, airplane, bus, train, truck and boat)
#
# ``--device`` whether you want to run your expirement on cuda device, i.e. 0 or 0,1,2,3 or cpu
#
# ``--imgsz`` inference size h,w

# %%
# !python track.py --source ./video.mkv --save-vid --yolo_model yolov5s.pt --show-vid --classes 1 2 3 4 5 6 7 8 --device cpu --imgsz 224
# Out:
# Successfully loaded imagenet pretrained weights from "C:\Users\Mohamad Al Mdfaa/.cache\torch\checkpoints\osnet_x0_25_imagenet.pth"
# D:\installed_programs\envs\edgevision\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'D:\installed_programs\envs\edgevision\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
# Results saved to runs\track\exp33\video.mkv
#   warn(f"Failed to load image Python extension: {e}")
# d:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\deep_sort/deep/reid\torchreid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# Selected model type: osnet_x0_25
# YOLOv5  2022-1-27 torch 1.10.1 CPU
#
# YOLOv5  2022-1-27 torch 1.10.1 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (6/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.051s), DeepSort:(2.469s)
# video 1/1 (7/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (8/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (9/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.046s), DeepSort:(0.017s)
# video 1/1 (10/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (11/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (12/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (13/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.047s), DeepSort:(0.018s)
# video 1/1 (14/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (15/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (16/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.049s), DeepSort:(0.015s)
# video 1/1 (17/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (18/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (19/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (20/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (21/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.048s), DeepSort:(0.018s)
# video 1/1 (22/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (23/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (24/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (25/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.019s)
# video 1/1 (26/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (27/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (28/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 2 buss, Done. YOLO:(0.046s), DeepSort:(0.019s)
# video 1/1 (29/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (30/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, Done. YOLO:(0.049s), DeepSort:(0.017s)
# video 1/1 (31/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (32/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (33/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 2 buss, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.019s)
# video 1/1 (34/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 buss, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.018s)
# video 1/1 (35/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (36/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.018s)
# video 1/1 (37/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.019s)
# video 1/1 (38/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (39/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, 1 truck, Done. YOLO:(0.047s), DeepSort:(0.018s)
# video 1/1 (40/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (41/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (42/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.046s), DeepSort:(0.017s)
# video 1/1 (43/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (44/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (45/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.049s), DeepSort:(0.019s)
# video 1/1 (46/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.050s), DeepSort:(0.016s)
# video 1/1 (47/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (48/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.048s), DeepSort:(0.018s)
# video 1/1 (49/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 bus, Done. YOLO:(0.049s), DeepSort:(0.016s)
# video 1/1 (50/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.048s), DeepSort:(0.017s)
# video 1/1 (51/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.018s)
# video 1/1 (52/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.048s), DeepSort:(0.017s)
# video 1/1 (53/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.045s), DeepSort:(0.018s)
# video 1/1 (54/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.017s)
# video 1/1 (55/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.051s), DeepSort:(0.017s)
# video 1/1 (56/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (57/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (58/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (59/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (60/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (61/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (62/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, 1 bus, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (63/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (64/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (65/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (66/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (67/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (68/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.018s)
# video 1/1 (69/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (70/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (71/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (72/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (73/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (74/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (75/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (76/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (77/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (78/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (79/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (80/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.054s), DeepSort:(0.016s)
# video 1/1 (81/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (82/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (83/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (84/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# No detections
# No detections
# video 1/1 (87/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# No detections
# video 1/1 (90/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (91/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (92/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (93/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.018s)
# No detections
# No detections
# No detections
# No detections
# video 1/1 (98/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (99/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (100/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (101/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (102/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# No detections
# No detections
# video 1/1 (105/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (106/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (107/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (108/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (109/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (110/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (111/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.017s)
# video 1/1 (112/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (113/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (114/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (115/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (116/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (117/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (118/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (119/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (120/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (121/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (122/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (123/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (124/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (125/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (126/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (127/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (128/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (129/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (130/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (131/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (132/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (133/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (134/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (135/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (136/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (137/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (138/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (139/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (140/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (173/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# No detections
# video 1/1 (175/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (176/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (177/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.015s)
# video 1/1 (178/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (179/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (180/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (181/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (182/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (183/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (184/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (185/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (186/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (187/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (188/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (189/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.050s), DeepSort:(0.019s)
# video 1/1 (190/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.053s), DeepSort:(0.017s)
# video 1/1 (191/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.060s), DeepSort:(0.016s)
# video 1/1 (192/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.048s), DeepSort:(0.016s)
# video 1/1 (193/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (194/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (195/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (196/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (197/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (198/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (199/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (200/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (201/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (202/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (203/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.015s)
# video 1/1 (204/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (205/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (206/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (207/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (208/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (209/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (210/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (211/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.018s)
# video 1/1 (212/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (213/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (214/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (215/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (216/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (217/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (218/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.017s)
# video 1/1 (219/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.052s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (340/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# No detections
# No detections
# video 1/1 (343/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (344/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# No detections
# video 1/1 (346/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.048s), DeepSort:(0.016s)
# video 1/1 (347/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.049s), DeepSort:(0.016s)
# video 1/1 (348/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (349/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (350/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (351/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (352/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (353/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (354/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (355/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (356/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (357/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (358/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (359/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (360/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (361/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (362/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (363/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (364/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (365/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (366/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.046s), DeepSort:(0.017s)
# video 1/1 (367/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (368/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (369/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (370/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (371/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (372/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (373/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.052s), DeepSort:(0.017s)
# video 1/1 (374/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.048s), DeepSort:(0.017s)
# video 1/1 (375/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (376/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (377/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (378/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (379/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (380/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (381/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (382/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (383/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (384/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (385/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (386/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.049s), DeepSort:(0.019s)
# video 1/1 (387/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.056s), DeepSort:(0.016s)
# video 1/1 (388/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.049s), DeepSort:(0.019s)
# video 1/1 (389/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (390/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (391/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (392/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (393/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (394/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (395/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (396/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (397/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (398/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (399/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (400/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (401/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (402/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (403/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (565/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (566/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (567/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (568/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (569/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (570/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (571/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (572/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (573/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (574/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (575/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 bus, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (576/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (577/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (578/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (579/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (580/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.043s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (588/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (600/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (601/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (602/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (603/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (604/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (605/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 2 cars, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (606/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (607/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (608/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.015s)
# video 1/1 (609/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (610/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (611/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (612/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (613/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.017s)
# video 1/1 (614/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (615/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (616/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (617/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.017s)
# video 1/1 (618/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (619/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (620/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (621/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (622/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (623/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (624/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (625/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (626/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (627/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (628/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (629/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (630/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (631/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (632/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (633/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (634/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# ...
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (2445/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2446/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2447/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (2448/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2449/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.017s)
# video 1/1 (2450/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2451/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (2452/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2453/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2454/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2455/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (2456/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2457/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.018s)
# video 1/1 (2458/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2459/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2460/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2461/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.057s), DeepSort:(0.019s)
# video 1/1 (2462/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (2463/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (2464/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.016s)
# video 1/1 (2465/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2466/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (2467/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2468/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.017s)
# video 1/1 (2469/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2470/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (2471/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2472/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2473/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2474/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2475/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2476/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2477/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2478/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2479/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2480/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (2481/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2482/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.018s)
# video 1/1 (2483/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2484/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2485/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (2601/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.046s), DeepSort:(0.015s)
# video 1/1 (2602/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (2612/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# video 1/1 (2614/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# No detections
# No detections
# No detections
# video 1/1 (2618/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (2619/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2620/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2621/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.017s)
# video 1/1 (2622/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.054s), DeepSort:(0.017s)
# No detections
# video 1/1 (2624/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.049s), DeepSort:(0.016s)
# video 1/1 (2625/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.048s), DeepSort:(0.015s)
# video 1/1 (2626/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2627/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.016s)
# video 1/1 (2628/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2629/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.047s), DeepSort:(0.015s)
# video 1/1 (2630/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2631/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (2632/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# No detections
# video 1/1 (2634/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2635/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2636/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2637/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2638/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2639/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.017s)
# video 1/1 (2640/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2641/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2642/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (2643/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2644/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.018s)
# video 1/1 (2645/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2646/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2647/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2648/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.043s), DeepSort:(0.015s)
# video 1/1 (2649/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2650/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2651/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2652/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2653/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.015s)
# video 1/1 (2654/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.045s), DeepSort:(0.016s)
# video 1/1 (2655/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.044s), DeepSort:(0.015s)
# video 1/1 (2656/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.016s)
# video 1/1 (2657/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2658/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.046s), DeepSort:(0.018s)
# video 1/1 (2659/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, 1 truck, Done. YOLO:(0.044s), DeepSort:(0.016s)
# video 1/1 (2660/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# video 1/1 (2665/2716) D:\private\job interviews\EdgeVision\Yolov5_DeepSort_Pytorch\video.mkv: 192x224 1 car, Done. YOLO:(0.045s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# Speed: 0.1ms pre-process, 44.6ms inference, 0.3ms NMS, 7.4ms deep sort update         per image at shape (1, 3, 224, 224)
